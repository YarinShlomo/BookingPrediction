# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Hotels.csv")

# %%
# Clean hotel name
newNames = []
for i in range(len(df.Name)):
    name = df.Name[i]
    if '\n' in name:
        name = name.split('\n')[1]
    newNames.append(name)
df['Name'] = newNames

# %%
# remove duplication of rows
df.drop_duplicates(keep = "first", inplace = True)

# %%
# Reset df indexing
df.head(50)
# Out:
#                                                  Name      City Price Rating  \
# 0    Schulz Hotel Berlin Wall at the East Side Gal...  Budapest   191    8.7
# 1          Novotel Suites Berlin City Potsdamer Platz  Budapest   259    8.2
# 2         NH Collection Berlin Mitte Friedrichstrasse  Budapest   371    8.8
# 3                  Ibis budget Berlin Potsdamer Platz  Budapest   156    7.8
# 4             Hollywood Media Hotel am Kurfürstendamm  Budapest   246    8.4
# 5                                Hotel Berlin, Berlin  Budapest   348    8.2
# 6                                Novotel Berlin Mitte  Budapest   262    8.4
# 7                       Motel One Berlin-Hauptbahnhof  Budapest   369    8.7
# 8                             ibis Hotel Berlin Mitte  Budapest   223    8.2
# 9                                        the niu Hide  Budapest   175    8.8
# 10                   Motel One Berlin-Potsdamer Platz  Budapest   369    8.7
# ...

# %%
# Remove rows where stars = 0
df = df[df.Stars != 0]

# %%
# Remove bad info from rating
df = df[df.Rating != "Read"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5786 entries, 0 to 6732
# Data columns (total 19 columns):
# Name                       5786 non-null object
# City                       5786 non-null object
# Price                      5786 non-null object
# Rating                     5786 non-null object
# Stars                      5786 non-null int64
# Reviews                    5786 non-null object
# Location                   5786 non-null float64
# Cleanliness                5786 non-null float64
# staff                      5786 non-null float64
# Comfort                    5786 non-null float64
# Value for Money            5786 non-null float64
# Facilities                 5786 non-null float64
# Wifi                       5750 non-null float64
# Closest attraction dist    5786 non-null float64
# Closest transportation     5728 non-null float64
# Closest airport            5786 non-null float64
# payment methods            5780 non-null float64
# ...

# %%
# Remove rows with missing values
df.dropna(axis=0, subset=['Wifi', "Allowing pets", "Closest attraction dist","payment methods"], inplace = True)

# %%
# replace np.nan -> 1 in Closest transportation col.
df['Closest transportation'].fillna(1, inplace = True)

# %%
df.reset_index(drop=True, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5710 entries, 0 to 5709
# Data columns (total 19 columns):
# Name                       5710 non-null object
# City                       5710 non-null object
# Price                      5710 non-null object
# Rating                     5710 non-null object
# Stars                      5710 non-null int64
# Reviews                    5710 non-null object
# Location                   5710 non-null float64
# Cleanliness                5710 non-null float64
# staff                      5710 non-null float64
# Comfort                    5710 non-null float64
# Value for Money            5710 non-null float64
# Facilities                 5710 non-null float64
# Wifi                       5710 non-null float64
# Closest attraction dist    5710 non-null float64
# Closest transportation     5710 non-null float64
# Closest airport            5710 non-null float64
# payment methods            5710 non-null float64
# ...

# %%
# Removing the ',' from numbers with more than 3 digits so we will be able to convert to float. 
df['Price'] = df['Price'].str.replace(',','')
df['Reviews'] = df['Reviews'].str.replace(',','')

# Converting columns to float.
df.astype({'Price':np.float64,'Reviews':np.float64}).dtypes
# Out:
# Name                        object
# City                        object
# Price                      float64
# Rating                      object
# Stars                        int64
# Reviews                    float64
# Location                   float64
# Cleanliness                float64
# staff                      float64
# Comfort                    float64
# Value for Money            float64
# Facilities                 float64
# Wifi                       float64
# Closest attraction dist    float64
# Closest transportation     float64
# Closest airport            float64
# payment methods            float64
# Number of languages          int64
# Allowing pets               object
# dtype: object

# %%
df.to_csv("CleanHotels.csv", index= False)
